# %% [markdown]
# <a href="https://colab.research.google.com/github/thanaprondtn/python_dataviz2024/blob/main/Pandas_101_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A': [1,2,3],'B': [2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A': [1,2,3],'B': [2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# # Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
folk_df = pd.read_csv('/content/folktales.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c1fdb6158f43> in <cell line: 1>()
# ----> 1 folk_df = pd.read_csv('/content/folktales.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# # Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os #os จัดการ path กับ file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_folktales = '/content/drive/MyDrive/Data_Viz_2024_Data570-8/folktales.csv'

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df.tail()
# Out:
#                    title             type                 creator  \
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# ...

# %%
folk_df.shape
# Out:
# (226, 11)

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv'
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
folk_df['title']
# Out:
# 0             ตาบอดคลำช้าง
# 1           ขอคำกระฮอกด่อน
# 2       ก่องข้าวน้อยฆ่าแม่
# 3                บักหำน้อย
# 4               รื้อบ่อน้ำ
#               ...
# 221            ตำนานมะโย่ง
# 222              ตำราหมอดู
# 223     เต่ากับพระพุทธเจ้า
# 224          ถ้ำคูหาสวรรค์
# 225    ถ้ำทองและถ้ำเปอร์งง
# Name: title, Length: 226, dtype: object

# %%
folk_df['title'][99]
# Out:
# 'เด็กโง่'

# %%
folk_df['creator'][99]
# Out:
# 'เรียบ รักสมบัติ'

# %% [markdown]
# #### .iloc

# %%
folk_df.iloc[99,5]
# Out:
# 'ไทย,'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title', 'type', 'creator', 'subject', 'spatial']]
smaller_table
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#            subject spatial
# 0    นิทานพื้นบ้าน     ไทย
# 1    นิทานพื้นบ้าน     ไทย
# 2    นิทานพื้นบ้าน     ไทย
# 3    นิทานพื้นบ้าน     ไทย
# 4    นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
folk_df.iloc[1:5,:]
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# ## Table Query (row)
# (Query ดึงข้อมูล)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ### อยากได้ นิทานที่เป็นมุขตลก

# %%
folk_df['type'] == 'มุขตลก'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 221    False
# 222     True
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df[folk_df['type'] == 'มุขตลก']
# Out:
#                                           title    type              creator  \
# 3                                     บักหำน้อย  มุขตลก      สมหวัง ปานพายัพ
# 4                                    รื้อบ่อน้ำ  มุขตลก       บุญศรี เกสเสโร
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ  มุขตลก   พัชราภรณ์ เข็มเพชร
# 7                                หลวงพ่อน้องงัว  มุขตลก      สุบิน คำยางจ้อง
# 8                             หลวงพ่อกับเณรน้อย  มุขตลก  ปรางค์ทิพย์ บุญสีลา
# 9                               หัวล้านหลื่นครู  มุขตลก        ใจมา สมจันทร์
# 11            เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ  มุขตลก     เพ็ญนภา พันพินิจ
# 18                                       จับราว  มุขตลก          ชารี คำสีมา
# 19                               บักแหมบกับอีทา  มุขตลก      สุนีย์ คุณโพธิ์
# 20                             แม่เฒ่ากับลูกเขย  มุขตลก      สุนีย์ คุณโพธิ์
# 22                            หลวงพ่อกลัวผีหลอก  มุขตลก          เสาร์ จันกอ
# ...

# %% [markdown]
# ##Quiz6 เลือก data มา 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
# แสดงวิธีทำดังนี้ 1.สร้าง list of logics
# 2. query

# %%
logic_list = [True]*10 + [False]*(folk_df.shape[0]-25) + [True]*15


result = folk_df[logic_list]
result
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %% [markdown]
# เฉลย

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (226-25)*[False]

# %%
folk_df[list_log1+list_logM+list_log2]
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %%
# prompt: create list that has 226 members where the first 10 and the last 15 are true,the rest are False

list_log1 = [True] * 10
list_log2 = [True] * 15
list_logM = [False] * (226 - 25)

combined_list = list_log1 + list_logM + list_log2

# %%
combined_list
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# # HW5
# ใช้การ Query และ Data Slicing เพื่อตอบคำถามต่อไปนี้
# 1. นิทานที่ยาวที่สุด และสั้นที่สุด (ไม่นับสัญลักษณ์พิเศษ)
# 2. ชนิดของนิทาน (type) ที่มากที่สุดและน้อยที่สุด
# 3. มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][0]
# Out:
# '    มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า\n\n   เราจะพาไปตั้งวงดนตรีจะไปไหม? เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ\n\n    ตาบอดคนหนึ่งพูดขึ้นมาว่านายจะร้องได้ไหม?\n\n    อีกคนตอบ มันจะยากอะไร\n\n    เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า\n\n   หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย\n\n    ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า นั่นช้างหรอ\n\n    ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้างเจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน\n\n    ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า\n\n    โอ้โห ช้างนี่มันเหมือนไม้กวาดเลย\n\n    คนที่สองเข้ามาไปจับโดนตรงขาช้าง แล้วก็บอกว่า\n\n    ช้างนี่เหมือนสูบตีเหล็กนะ\n\n   คนที่สามเข้ามาทางด้านข้างของช้าง ก็จับดูทางด้านข้าง\n\n    โอ้ ช้างนี่เหมือนผนังยุ้งข้าวเลย\n\n     คนที่สี่เข้ามาถึง ก็จับไปโดนหูช้าง\n\n    โอ้ ช้างนี่เหมือนภาชนะสำหรับฝัดข้าวเลย\n\n     พอคนที่ห้าเข้ามาถึง ก็เข้าไปจับโดนมือช้างหรืองวงช้าง ก็
# ...

# %%
import pandas as pd
import string
import os #os จัดการ path กับ file
from google.colab import drive
drive.mount('/content/drive')
path_to_folktales = '/content/drive/MyDrive/Data_Viz_2024_Data570-8/folktales.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
# Ensure the 'description' column is of type string
folk_df['description'] = folk_df['description'].astype(str)

# ลบสัญลักษณ์พิเศษออกจากเนื้อหา
def remove_special_characters(text):
    return text.translate(str.maketrans('', '', string.punctuation))

    folk_df['description'] = folk_df['description'].apply(remove_special_characters)

# %%
# 1. นิทานที่ยาวที่สุดและสั้นที่สุด (ไม่นับสัญลักษณ์พิเศษ)
folk_df['description_length'] = folk_df['description'].apply(len) # Create new column for length
longest_story = folk_df.loc[folk_df['description_length'].idxmax()]
shortest_story = folk_df.loc[folk_df['description_length'].idxmin()]

print("นิทานที่ยาวที่สุด คือ")
print(longest_story[['title', 'description_length']])
print("นิทานที่สั้นที่สุด คือ")
print(shortest_story[['title', 'description_length']])
# Out:
# นิทานที่ยาวที่สุด คือ
# title                 ท้าวหมาหยุ๋ย
# description_length            7863
# Name: 26, dtype: object
# นิทานที่สั้นที่สุด คือ
# title                 บอดตาใส
# description_length          3
# Name: 27, dtype: object

# %%
# 2. ชนิดของนิทาน (type) ที่มากที่สุดและน้อยที่สุด
type_counts = folk_df['type'].value_counts()
most_common_type = type_counts.idxmax()
least_common_type = type_counts.idxmin()

print("ชนิดของนิทานที่มากที่สุด:", most_common_type)
print("ชนิดของนิทานที่น้อยที่สุด:", least_common_type)
# Out:
# ชนิดของนิทานที่มากที่สุด: มุขตลก
# ชนิดของนิทานที่น้อยที่สุด: นิทานเข้าแบบ

# %%
# 3. มี spatial ที่ไม่ใช่ไทยกี่เรื่อง
non_thai_spatial_count = folk_df[folk_df['spatial'] != 'ไทย'].shape[0]

print("จำนวนเรื่องที่มี spatial ที่ไม่ใช่ไทย คือ", non_thai_spatial_count)
# Out:
# จำนวนเรื่องที่มี spatial ที่ไม่ใช่ไทย คือ 146

# %% [markdown]
# เฉลย

# %%
# prompt: ลบ row ที่มีค่าว่างใน column description

folk_df = folk_df.dropna(subset=['description'])

# %%
# prompt: เทียบ ปริมาณ data ก่อน และ หลัง ลบค่าว่าง

print("Shape of the DataFrame before removing missing values:")
print(folk_df.shape)

# Drop missing values in the 'description' column
folk_df = folk_df.dropna(subset=['description'])

print("Shape of the DataFrame after removing missing values:")
print(folk_df.shape)
# Out:
# Shape of the DataFrame before removing missing values:
# (226, 11)
# Shape of the DataFrame after removing missing values:
# (226, 11)

# %%
# prompt: ลบ html tagsและ html codes ออกจาก text ใน column description ใช้ beautifulsoup

from bs4 import BeautifulSoup

def remove_html(text):
  soup = BeautifulSoup(text, "html.parser")
  return soup.get_text()

folk_df['description'] = folk_df['description'].apply(remove_html)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0      มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ...  นิทานพื้นบ้าน     ไทย
# 1     ในขณะนั้นมีพญาผู้หนึ่งชื่อว่า พญาขอม ครองเม...  นิทานพื้นบ้าน     ไทย
# 2  ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำกล้...  นิทานพื้นบ้าน     ไทย
# 3  เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอีสาน...  นิทานพื้นบ้าน     ไทย
# 4  วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ พอข...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# เฉลย

# %%
# prompt: ลบค่าว่างใน column type

folk_df['type'].dropna(inplace=True)

# %%
# prompt: ชนิดของนิทาน (type) ที่มีจำนวน row มากที่สุดและน้อยที่สุดและนับจำนวน ใช้ index

type_counts = folk_df['type'].value_counts()
most_common_type = type_counts.idxmax()
least_common_type = type_counts.idxmin()

print("ชนิดของนิทานที่มากที่สุด:", most_common_type, "จำนวน:", type_counts[most_common_type])
print("ชนิดของนิทานที่น้อยที่สุด:", least_common_type, "จำนวน:", type_counts[least_common_type])
# Out:
# ชนิดของนิทานที่มากที่สุด: มุขตลก จำนวน: 51
# ชนิดของนิทานที่น้อยที่สุด: นิทานเข้าแบบ จำนวน: 1

# %% [markdown]
# ทำเอง

# %%
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          41       22           41       41       35         0
# นิทานประจำถิ่น      26       15           26       26       24         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          15        5           15       15       12         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              51       33           51       51       47         0
#
#                  language  rights  license  source.uri
# type
# ...

# %% [markdown]
# ### HW 5.3 มี spatial ที่ไม่ใช่ไทยกี่เรื่อง

# %%
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
set(folk_df['spatial']) #set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df = folk_df.dropna(subset=['spatial'])

# %%
folk_df.shape[0]
# Out:
# 200

# %% [markdown]
# ##การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = folk_df.copy()

# %%
this_data.shape #(12423, 3)
# Out:
# (226, 11)

# %%
print(this_data.shape)
print(this_data.dropna().shape) #ข้อเสีย ถ้าไมไ่ด้เลือกcolumn ที่ถูกต้องมันจะหายไปหมด dataหายไป100%
# Out:
# (226, 11)
# (0, 11)

# %%
this_data.dropna().shape
# Out:
# (0, 11)

# %%
this_data.dropna()
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (226, 11)

# %%
this_data.dropna(inplace=True)

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = folk_df.copy()

# %%
this_data
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = this_data.dropna(inplace=True)

# %%
this_data

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title','description','type']) #สมมติ เราต้องใช้ ค่าใน column 'title','description','type'

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['type'].mode() #ไม่ใช่ตัวเลข ใช้ได้แค่mode
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull() #isnull #checkว่าcolumnไหนเป็นค่าว่างบ้าน
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any() # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
folk_df['type'].isnull().all() # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %% [markdown]
# #Quiz 7 นิทานเรื่องไหนที่ ค่า spatial เป็น ค่าว่าง

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
# prompt: หาค่าซ้ำใน column title

duplicate_titles = folk_df[folk_df.duplicated(subset='title')]
print(duplicate_titles['title'])
# Out:
# 32     ก่องข้าวน้อยฆ่าแม่
# 43     ก่องข้าวน้อยฆ่าแม่
# 75              พญาคันคาก
# 95           กำพร้าผีน้อย
# 100              ผีกองกอย
# 142              ผีกองกอย
# Name: title, dtype: object

# %%
folk_df['title'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: title, Length: 226, dtype: bool

# %%
folk_df['title'].duplicated().any()
# Out:
# True

# %%
folk_df[folk_df['title'].duplicated(keep=False)] #inputที่จำเป็น0ตัว
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.fillna({'type':folk_df['type'].mode()})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-1, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#           sex  age province_of_onset
# 4391   ไม่รู้ -1.0         สมุทรสาคร
# 4392   ไม่รู้ -1.0         สมุทรสาคร
# 4393   ไม่รู้ -1.0         สมุทรสาคร
# 4394   ไม่รู้ -1.0         สมุทรสาคร
# 4395   ไม่รู้ -1.0         สมุทรสาคร
# ...       ...  ...               ...
# 12635  ไม่รู้ -1.0         สมุทรสาคร
# 12636  ไม่รู้ -1.0         สมุทรสาคร
# 12637  ไม่รู้ -1.0         สมุทรสาคร
# 12638  ไม่รู้ -1.0         สมุทรสาคร
# 12639  ไม่รู้ -1.0         สมุทรสาคร
#
# [2502 rows x 3 columns]

# %%
this_data_updated['province_of_onset']=='ไม่รู้'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[this_data_updated['province_of_onset']=='ไม่รู้']
# Out:
#          No.  ...                                         risk
# 414      415  ...                                      สนามมวย
# 529      530  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 555      556  ...                                      สนามมวย
# 576      577  ...                                      สนามมวย
# 588      589  ...                         อยู่ระหว่างการสอบสวน
# ...      ...  ...                                          ...
# 12405  12406  ...                            Cluster สมุทรสาคร
# 12406  12407  ...                            Cluster สมุทรสาคร
# 12407  12408  ...                            Cluster สมุทรสาคร
# 12408  12409  ...                            Cluster สมุทรสาคร
# 12409  12410  ...                            Cluster สมุทรสาคร
#
# [1991 rows x 10 columns]

# %%
this_data_updated_2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated_2[this_data_updated['sex']=='ไม่รู้']
# Out:
#        sex  age province_of_onset
# 4391   NaN  NaN         สมุทรสาคร
# 4392   NaN  NaN         สมุทรสาคร
# 4393   NaN  NaN         สมุทรสาคร
# 4394   NaN  NaN         สมุทรสาคร
# 4395   NaN  NaN         สมุทรสาคร
# ...    ...  ...               ...
# 12635  NaN  NaN         สมุทรสาคร
# 12636  NaN  NaN         สมุทรสาคร
# 12637  NaN  NaN         สมุทรสาคร
# 12638  NaN  NaN         สมุทรสาคร
# 12639  NaN  NaN         สมุทรสาคร
#
# [2502 rows x 3 columns]

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
this_data = folk_df[['title','type','creator']].dropna() #เลือกคอลัมภ์ และดรอปค่าว่าง

# %%
this_data
# Out:
#                        title             type                 creator
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 217                   เณรทอง   นิทานประจำถิ่น         รมย์   เผือกแสง
# 218         ดวงอาทิตย์กับไก่  นิทานอธิบายเหตุ         รมย์   เผือกแสง
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
#
# [125 rows x 3 columns]

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n***********************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# ***********************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# ***********************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# ***********************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# ***********************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# ***********************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# ***********************
# (6, title        ตำนานกุดนางใย
# ...

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    if (each_row[1]['age'] == 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)

# %% [markdown]
# ##Quiz 9 วนลูปนับนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
# -มีคำดังกล่าวในนิทานชีวิต หรือนิทานประถิ่นมากกว่ากัน
# -คนแต่งคนไหนชอบแต่งนิทานที่มีชื่อเรื่องว่าแม่หรือพ่อมากที่สุด

# %%
# prompt: วนลูปนับชื่อนิทานที่มีคำว่าแม่หรือพ่อ กี่เรื่องและเรื่องอะไรบ้าง use this_data

count = 0
stories_with_parent = []
for _, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    count += 1
    stories_with_parent.append(row['title'])

print(f"มีนิทานที่มีคำว่า แม่ หรือ พ่อ อยู่ {count} เรื่อง")
print("รายชื่อนิทาน:")
for story in stories_with_parent:
  print(story)
# Out:
# มีนิทานที่มีคำว่า แม่ หรือ พ่อ อยู่ 19 เรื่อง
# รายชื่อนิทาน:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
# prompt: มีคำว่าแม่หรือพ่อในนิทานชีวิต หรือนิทานประถิ่นมากกว่ากันเท่าไหร่  use this_data

life_count = 0
local_count = 0

for _, row in this_data.iterrows():
  if ('แม่' in row['title'] or 'พ่อ' in row['title']):
    if row['type'] == 'นิทานชีวิต':
      life_count += 1
    elif row['type'] == 'นิทานประจำถิ่น':
      local_count += 1

difference = abs(life_count - local_count)
more_type = "นิทานชีวิต" if life_count > local_count else "นิทานประจำถิ่น"

print(f"มีคำว่า แม่ หรือ พ่อ ใน {more_type} มากกว่า {difference} เรื่อง")
# Out:
# มีคำว่าแม่หรือพ่อในนิทานชีวิตและนิทานประจำถิ่นเท่ากัน

# %%
# prompt: คนแต่งคนไหนชอบแต่งนิทานที่มีชื่อเรื่องว่าแม่หรือพ่อมากที่สุด use this_data (พร้อมทั้งอธิบายโค้ดแต่ละบรรทัด)

creator_counts = {}  # สร้าง dictionary (ต้องเช็คว่าindexเคยมีรึเปล่า) เพื่อเก็บจำนวนนิทานของแต่ละคนแต่ง

for _, row in this_data.iterrows():  # วนลูปดูแต่ละแถวในตาราง
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:  # ถ้าชื่อเรื่องมีคำว่า 'แม่' หรือ 'พ่อ'
    creator = row['creator']  # เก็บชื่อคนแต่ง
    if creator not in creator_counts:  # ถ้าคนแต่งยังไม่อยู่ใน dictionary
      creator_counts[creator] = 0  # เพิ่มคนแต่งเข้าไปใน dictionary พร้อมจำนวนเริ่มต้นเป็น 0
    creator_counts[creator] += 1  # เพิ่มจำนวนนิทานของคนแต่งนั้น

# หาคนแต่งที่มีจำนวนนิทานมากที่สุด
max_count = 0
top_creator = ""
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    top_creator = creator

print(f"คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่าแม่หรือพ่อมากที่สุดคือ {top_creator} แต่งไป {max_count} เรื่อง")
# Out:
# คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่าแม่หรือพ่อมากที่สุดคือ หนูเวียง แก้วเวียง แต่งไป 2 เรื่อง

# %%
creator_counts
# Out:
# {'หนูเวียง แก้วเวียง': 2,
#  'สุบิน คำยางจ้อง': 1,
#  'ปรางค์ทิพย์ บุญสีลา': 1,
#  'ชลิตา โพธิสาร': 1,
#  'ไพบูลย์ ระหา': 1,
#  'สุนีย์ คุณโพธิ์': 1,
#  'เสาร์ จันกอ': 2,
#  'จันทร์ โพธิ์ไทสง': 1,
#  'อ่อนตา ประกาเวสา': 2,
#  'สมศรี ถอนภูเขียว': 1,
#  'พรม วรรณศิริ': 1,
#  'สุรพันธ์ บุญชู': 1,
#  'เลิศ ประนัดเด': 1,
#  'อาคม  ปาสานัย': 1,
#  'ลาภ  เพ็ญสวัสดิ์': 1,
#  'นวลจันทร์  จีนเมือง': 1}

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9
# print ชื่อนิทานทั้งหมดที่มีคำว่า พ่อ หรือแม่ ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา ใช้ iloc

for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
# Out:
# เขาปู่เขาย่า

# %% [markdown]
# #Dataset ใหม่ ที่มี ตัวเลข

# %%
import pandas as pd

# %%
import os #os จัดการ path กับ file
from google.colab import drive
drive.mount('/content/drive')
path_to_movie = '/content/drive/MyDrive/Data_Viz_2024_Data570-8/IMDb Movies India.csv'
# Out:
# Mounted at /content/drive

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/Data_Viz_2024_Data570-8/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: movie_df ถ้า dropna จะหายไปกี่เปอร์เซ็นต์

# Calculate the percentage of rows lost after dropna()
initial_rows = movie_df.shape[0]
rows_after_dropna = movie_df.dropna().shape[0]
percentage_lost = ((initial_rows - rows_after_dropna) / initial_rows) * 100

print(f"Percentage of rows lost after dropna(): {percentage_lost:.2f}%")
# Out:
# Percentage of rows lost after dropna(): 63.51%

# %%
movie_df = movie_df.dropna()

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %%
# Convert 'Votes' back to string type before applying string operations
movie_df['Votes'] = movie_df['Votes'].astype(str)

# Remove commas and convert 'Votes' to integers
movie_df['Votes'] = movie_df['Votes'].str.replace(',', '').astype(int)

# %%
movie_df
# Out:
#                                      Name    Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)       109
# 3                                 #Yaaram  (2019)       110
# 5                    ...Aur Pyaar Ho Gaya  (1997)       147
# 6                               ...Yahaan  (2005)       142
# 8                      ?: A Question Mark  (2012)        82
# ...                                   ...     ...       ...
# 15493                              Zubaan  (2015)       115
# 15494                            Zubeidaa  (2001)       153
# 15503                     Zulm Ki Zanjeer  (1989)       125
# 15505                               Zulmi  (1999)       129
# 15508                        Zulm-O-Sitam  (1998)       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#           Duration       Rating          Votes
# count  5659.000000  5659.000000    5659.000000
# mean    133.439124     5.898533    2697.649585
# std      25.319939     1.381165   13651.503584
# min      21.000000     1.100000       5.000000
# 25%     119.000000     5.000000      30.000000
# 50%     135.000000     6.100000     131.000000
# 75%     150.000000     6.900000     922.500000
# max     321.000000    10.000000  591417.000000

# %% [markdown]
# สร้างตารางของ Director ที่มี Name เยอะที่สุด

# %%
# prompt: สร้าง ตารางของ Director ที่มี Name เยอะที่สุด เอาแค่ข้อมูลของคนที่เยอะที่สุด

director_counts = movie_df['Director'].value_counts()
top_director = director_counts.index[0]
top_director_df = movie_df[movie_df['Director'] == top_director]
top_director_df
# Out:
#                                     Name    Year  Duration  \
# 239                          Aag Ka Gola  (1990)       180
# 397                            Aandhiyan  (1990)       145
# 408                              Aankhen  (1993)       170
# 1008                               Andaz  (1994)       167
# 1596              Bade Miyan Chote Miyan  (1998)       140
# 1794                       Banarasi Babu  (1997)       126
# 2408                          Biwi No. 1  (1999)       159
# 2478                       Bol Radha Bol  (1992)       164
# 2754                      Chal Mere Bhai  (2000)       136
# 2903                     Chashme Baddoor  (2013)       121
# 3098                  Chor Machaaye Shor  (2002)       145
# 3230                        Coolie No. 1  (1995)       143
# 3232                        Coolie No. 1  (2020)       134
# 3562                     Deewana Mastana  (1997)       140
# 4037                     Do Knot Disturb  (2009)       126
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == top_director]['Rating'].mean()
# Out:
# 5.226829268292683

# %%
movie_df[movie_df['Director'] == top_director].describe()
# Out:
#          Duration     Rating         Votes
# count   41.000000  41.000000     41.000000
# mean   145.170732   5.226829   4283.585366
# std     15.006503   1.060430   8914.061860
# min    121.000000   2.900000     23.000000
# 25%    134.000000   4.600000    887.000000
# 50%    143.000000   5.100000   2299.000000
# 75%    160.000000   6.100000   4840.000000
# max    180.000000   6.700000  56232.000000

# %% [markdown]
# # HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง and present 3 นาที codeใส่แค่สั่งว่าอะไร เอาแค่อันที่น่าสนใจ

# %% [markdown]
# ใช้จำนวนหนังเป็นเกณฑ์ โดยดู rating ประกอบด้วย

# %%
# prompt: หาผู้กำกับ 3 อันดับแรกที่มีจำนวนหนังเยอะที่สุด คะแนนเฉลี่ยของหนังทั้งหมด หนังที่มีคะแนนสูงสุด หนังที่มีคนโหวตเยอะที่สุด

# 1. หาผู้กำกับ 3 อันดับแรกที่มีจำนวนหนังเยอะที่สุด
top_3_directors = movie_df['Director'].value_counts().head(3).index.tolist()

# 2. วนลูปดูข้อมูลของผู้กำกับแต่ละคน
for director in top_3_directors:
  # 2.1 เลือกข้อมูลหนังของผู้กำกับคนนั้น
  director_movies = movie_df[movie_df['Director'] == director]

  # 2.2 คำนวณค่าเฉลี่ย Rating ของหนังทั้งหมดของผู้กำกับคนนั้น
  average_rating = director_movies['Rating'].mean()

  # 2.3 หาหนังที่มี Rating สูงสุดของผู้กำกับคนนั้น
  top_rated_movie = director_movies.loc[director_movies['Rating'].idxmax()]

  # 2.4 หาหนังที่มี Votes เยอะที่สุดของผู้กำกับคนนั้น
  most_voted_movie = director_movies.loc[director_movies['Votes'].idxmax()]

  # 2.5 พิมพ์ข้อมูลสรุปของผู้กำกับคนนั้น
  print(f"ผู้กำกับ: {director}")
  print(f"จำนวนหนังที่กำกับ: {director_movies.shape[0]} เรื่อง")
  print(f"คะแนนเฉลี่ยของหนังทั้งหมด: {average_rating:.2f}")
  print(f"หนังที่มีคะแนนสูงสุด: {top_rated_movie['Name']} ({top_rated_movie['Rating']})")
  print(f"หนังที่มีคนโหวตเยอะที่สุด: {most_voted_movie['Name']} ({most_voted_movie['Votes']} โหวต)")
  print("-" * 30)
# Out:
# ผู้กำกับ: David Dhawan
# จำนวนหนังที่กำกับ: 41 เรื่อง
# คะแนนเฉลี่ยของหนังทั้งหมด: 5.23
# หนังที่มีคะแนนสูงสุด: Aankhen (6.7)
# หนังที่มีคนโหวตเยอะที่สุด: Coolie No. 1 (56232 โหวต)
# ------------------------------
# ผู้กำกับ: Mahesh Bhatt
# จำนวนหนังที่กำกับ: 39 เรื่อง
# คะแนนเฉลี่ยของหนังทั้งหมด: 5.75
# หนังที่มีคะแนนสูงสุด: Saaransh (8.2)
# หนังที่มีคนโหวตเยอะที่สุด: Sadak 2 (67785 โหวต)
# ------------------------------
# ผู้กำกับ: Ram Gopal Varma
# จำนวนหนังที่กำกับ: 33 เรื่อง
# คะแนนเฉลี่ยของหนังทั้งหมด: 5.60
# หนังที่มีคะแนนสูงสุด: Satya (8.2)
# หนังที่มีคนโหวตเยอะที่สุด: Sarkar (16038 โหวต)
# ------------------------------

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
